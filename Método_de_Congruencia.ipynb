# %% [markdown]
# <a href="https://colab.research.google.com/github/XiadaniCue/Simulaci-n-1/blob/main/M%C3%A9todo_de_Congruencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Método de Congruencia
#
# Xiadani Paola Reyes Cuellar

# %%
#Con este método buscamos generar números aleatorios, donde la longitud de nuestros números aleatorios se detemina por el tamaño de m

from os import major

#Semilla
x0=6
# divisor
m=16
#Constantes
a=5
c=5
suma=0

listN=[]
listx0=[6]
listmod=[]
listxn=[]
listdiv=[]

#print ('N | x0 | módulo | xn | xn/m ')
for n in range(0,20):
  #x=a*xn + c
  x=(a*x0)+c
  xmod= x%m
  div=x0/m
  #print (n, ',', x0, ',',  x, ',', xmod, ',', div)
  x0=xmod

  suma=x0+suma
  media=suma/20

  listN.append(n)
  listx0.append(x0)
  listmod.append(x)
  listxn.append(xmod)
  listdiv.append(div)


#print(listdiv)
#m es quien define la longitud

# %%
from IPython.display import display
import pandas as pd

#tabla = pd.DataFrame(listx0, columns=["x0"])
tabla= pd.DataFrame((list(zip(listx0, listmod, listxn, listdiv))), columns=["x0", "a*x0+c", "módulo", "xn/m"])

dataframe = pd.DataFrame(tabla)
display(dataframe)

#print(dataframe)
# Out:
#     x0  a*x0+c  módulo    xn/m
# 0    6      35       3  0.3750
# 1    3      20       4  0.1875
# 2    4      25       9  0.2500
# 3    9      50       2  0.5625
# 4    2      15      15  0.1250
# 5   15      80       0  0.9375
# 6    0       5       5  0.0000
# 7    5      30      14  0.3125
# 8   14      75      11  0.8750
# 9   11      60      12  0.6875
# 10  12      65       1  0.7500
# 11   1      10      10  0.0625
# 12  10      55       7  0.6250
# 13   7      40       8  0.4375
# 14   8      45      13  0.5000
# 15  13      70       6  0.8125
# 16   6      35       3  0.3750
# 17   3      20       4  0.1875
# 18   4      25       9  0.2500
# 19   9      50       2  0.5625
